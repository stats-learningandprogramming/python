# %%
# Introduction of the jupyter extension
# Author : JiHoon Kim

# %% [markdown]
# # Image insertion

# %%
# !pip install IPython 
from IPython.display import Image
# code block
Image("img/jupyter_rise_install_code.png")

# %% [markdown]
# https://gifmaker.me/

# %% [markdown]
# Markdown
# ![rise](img/jupyter_rise_install_code.png "rise")

# %% [markdown]
# HTML img tag
# <center><img src="img/jupyter_rise_install_code.png"></center>

# %% [markdown]
# ![rise](img/jupyter_rise_installation.gif)

# %% [markdown]
# <img src="img/jupyter_rise_installation.gif" alt="rise installation" width="80%" height="80%">

# %% [markdown]
# <center><img src="img/jupyter_rise_installation.gif" width="300" height="300"></center>

# %% [markdown]
# # Video insertion

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('QHdIFeZWgLE')

# %% [markdown]
# # Slide function

# %% [markdown]
# Rise

# %% [markdown]
# https://jupyterlab.readthedocs.io/en/stable/user/export.html

# %% [markdown]
# https://rise.readthedocs.io/en/stable/resources.html

# %% [markdown]
# Please be aware that as of 5.3 RISE is unfortunately not yet compatible with JupyterLab and must be used with the classic notebook.

# %%
def link(url):
    return url.replace("https://www.youtube.com/watch?v=","")

path = "https://www.youtube.com/watch?v=sXyFa_r1nxA"

YouTubeVideo(link((path)))

# %% [markdown]
# # Markdown key

# %% [markdown]
# https://www.tablesgenerator.com/markdown_tables
